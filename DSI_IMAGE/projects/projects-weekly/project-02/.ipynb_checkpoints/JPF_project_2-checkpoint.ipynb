# %% [markdown]
# Needed for Reproduction
# =======================
#
# + Detail on Control Group
# + Observational Methods
# + Sample Size/Composition
# + Treatment of Outliers
# + Definitions
# + Hypothesis - how you arrived at it
# + Assumptions
# + OS and versions - software/computers
#
# Hypothesis:
# ------------
#
# + A song less than 3:30 has a higher chance of breaking into Top 10 than a longer song.
# + songs that entered the Top 100 during X season are more likely to stay in Top100 longer
# + An artist that has been in Top100 once has greater chance of breaking into Top 10
# + Group dynamics .. individual artist vs. same artist in group
# + is meteoric rise based on Genre?
#
# Function: Melt
#
# Fundamental Problems with Billboard data ??
#
# + http://kosu.org/post/commerce-vs-consumption-revolutionary-rethink-billboards-album-chart
# + http://www.modestinsights.com/analyzing-the-billboard-hot-100/
#
# ## Characteristics of a good tests
# - Specific: The question and key success metrics are clearly defined
# - Measurable: The question is one that can be measured with your data
# - Attainable: The question you are asking is possible to answer with the data you can collect
# - Reproducible: Another person (or you in 6 months!) can replicate your analysis
# - Time-bound: The question can be answered given real-world constraints of time and money

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import datetime

def xldate_to_datetime(xldate):
	temp = datetime.datetime(1900, 1, 1)
	delta = datetime.timedelta(days=xldate)
	return temp+delta

df = pd.read_csv('assets/all_billboard_data.txt', delimiter='|')

HEAD = 0


if HEAD > 0:
    snip_df = df.head(HEAD)
else:
    snip_df = df

#DELETE ALL NaN DATE OF ENTRIES    
snip_df = snip_df[snip_df['chart entry date'].notnull()]

# %%
YEAR_START = 1990
YEAR_END = 2000

#CONVERT EXCEL DATE TO STANDARD DATETIME
snip_df['chart.enter.date'] = snip_df['chart entry date'].apply(xldate_to_datetime)

#INITIALIZE CHART ENTER MONTH AND YEAR
snip_df['chart.enter.month'] = snip_df['chart.enter.date'].apply(lambda x: x.month)
snip_df['chart.enter.year'] = snip_df['chart.enter.date'].apply(lambda x: x.year)

#rint snip_df[(snip_df['chart.enter.year'] > YEAR_START) & (snip_df['chart.enter.year'] < YEAR_END )].head(2)
#print snip_df[snip_df['chart.enter.month'] == 12].head(2)

#print snip_df.dtypes

snip_df = snip_df[(snip_df['chart.enter.year'] >= YEAR_START) & (snip_df['chart.enter.year'] <= YEAR_END )]
print snip_df['chart.enter.year'].unique()
print snip_df.shape
print snip_df['chart.enter.month'].value_counts()
#data.groupby(['col1', 'col2'])['col3'].mean()
trim = snip_df.pivot_table(values=['overall weeks on chart'],columns=['title'],aggfunc=max).T.reset_index()
trim
#snip_df[snip_df['overall weeks on chart'] == 1]

#trim = snip_df.groupby(['overall weeks on chart']).max()
#trim
#plt.figure()
sns.pairplot(data=snip_df[['chart.enter.year','overall weeks on chart','overall peak']], dropna=True)
sns.pairplot(data=snip_df[['chart.enter.month','overall weeks on chart','overall peak']], dropna=True)
#plt.savefig("1_seaborn_pair_plot.png")
# Out:
# [2000 1999 1998 1997 1996 1995 1994 1993 1992 1991 1990]
# (57499, 14)
# 12    5718
# 3     5462
# 8     5056
# 10    5018
# 7     4924
# 6     4755
# 11    4719
# 5     4706
# 4     4666
# 2     4538
# 9     4270
# 1     3667
# Name: chart.enter.month, dtype: int64

# %%
df.dtypes
# Out:
# pos                         int64
# last week                  object
# peak                      float64
# weeks on chart            float64
# title                      object
# artist                     object
# chart entry date          float64
# entry position            float64
# overall peak              float64
# overall weeks on chart    float64
# chart date                  int64
# dtype: object

# %%
import pandas as pd
import numpy as np

def replace_nulls(value):
    if value == '*':
        return np.nan
    else:
        return value
    
def stndz_genres(value):
    if 'roll' in value:
        return 'Rock'
    elif value == 'R & B':
        return 'R&B'
    else:
        return value

def cleanTime(value):
    value.split(',')[2]
    duration = (int(value.split(',')[0]) * 60) + int(value.split(',')[1])
    return duration
    
#objects to ints on the week columns

#df.to_numeric(errors=ignore)

df = pd.read_csv('assets/billboard.csv')
df.head()
df.dtypes
df['genre'].unique()
df['genre'] = df['genre'].apply(stndz_genres)
df['time'].unique()
df['time'] = df['time'].apply(cleanTime) #convert strange "time" to seconds
df.rename(columns={'time': 'duration'}, inplace=True)

df.columns

df = df.applymap(replace_nulls) #convert "*" to "NaN" on all xN.week columns
df.iloc[:,7:] = df.iloc[:,7:].apply(pd.to_numeric,errors='ignore') #cast column to FLOAT (after we've altered * to 'NaN')
df['chart_weeks'] = df.iloc[:,7:].count(axis=1) #add column which calcs the num weeks on chart
df['date.entered'] = pd.to_datetime(df['date.entered'])
df['date.peaked'] = pd.to_datetime(df['date.peaked'])

df
#df[df['genre'] == 'Country']
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
sorted(df['date.entered'].unique())
# Out:
# ['April 1, 2000',
#  'April 15, 2000',
#  'April 22, 2000',
#  'April 29, 2000',
#  'April 8, 2000',
#  'August 12, 2000',
#  'August 19, 2000',
#  'August 26, 2000',
#  'August 5, 2000',
#  'December 11, 1999',
#  'December 16, 2000',
#  'December 18, 1999',
#  'December 2, 2000',
#  'December 23, 2000',
#  'December 25, 1999',
#  'December 30, 2000',
#  'December 4, 1999',
#  'February 12, 2000',
#  'February 19, 2000',
#  'February 26, 2000',
#  'February 5, 2000',
#  'January 1, 2000',
#  'January 15, 2000',
#  'January 22, 2000',
#  'January 29, 2000',
#  'January 8, 2000',
#  'July 1, 2000',
#  'July 15, 2000',
#  'July 17, 1999',
#  'July 22, 2000',
#  'July 29, 2000',
#  'July 8, 2000',
#  'June 10, 2000',
#  'June 17, 2000',
#  'June 24, 2000',
#  'June 3, 2000',
#  'June 5, 1999',
#  'March 11, 2000',
#  'March 18, 2000',
#  'March 25, 2000',
#  'March 4, 2000',
#  'May 13, 2000',
#  'May 20, 2000',
#  'May 27, 2000',
#  'May 6, 2000',
#  'November 11, 2000',
# ...
