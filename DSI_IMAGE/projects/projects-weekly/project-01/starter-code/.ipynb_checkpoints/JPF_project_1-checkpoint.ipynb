# %% [markdown]
# # Project 1
#
# ## Step 1: Open the `sat_scores.csv` file. Investigate the data, and answer the questions below.

# %% [markdown]
# ##### 1. What does the data describe?

# %% [markdown]
# The data describes 1) the participation Rate as a whole number percentage 2) the average Verbal scores and 3) the average Math scores by state, and nationally, for the 2001 SAT

# %% [markdown]
# ##### 2. Does the data look complete? Are there any obvious issues with the observations?

# %% [markdown]
# Yes, the data seems complete. I see no obvious issues. There is an entry for each "State" plus an additional entry named "All" for national averages and an entry for D.C. which isn't technically a State. For the purposes of this project, 'All' will be removed from the data as it is itself, a derived entry.

# %% [markdown]
# ##### 3. Create a data dictionary for the dataset.

# %% [markdown]
# "sat_scores.csv"
# <br>1 header row of the following values: State, Rate, Verbal, Math
# <br>*State* -- string, State of the testing
# <br>*Rate* --  float, percentage of participation for that 'state'
# <br>*Verbal* --  float, Average value of Verbal Score within that State
# <br>*Math* --  float, Average value of Math score within that State
# <br>*NOTE1: there is also a 'summary' row denoted by "All" in the State column which represents the national averages*
# <br>*NOTE2: Washington, DC is treated as a "State"*

# %% [markdown]
# ## Step 2: Load the data.

# %% [markdown]
# ##### 4. Load the data into a list of lists

# %%
import csv

sat_score_list = []
with open("/Users/jfreeley/GA-DSI/DSI_IMAGE/projects/projects-weekly/project-01/assets/sat_scores.csv", "r") as fp:
    list = csv.reader(fp) 
    sat_score_list = [row for row in list] #treat each row as a list and create a list entry for each row

# %% [markdown]
# ##### 5. Print the data

# %%
sat_score_list
# Out:
# [['State', 'Rate', 'Verbal', 'Math'], ['CT', '82', '509', '510'], ['NJ', '81', '499', '513'], ['MA', '79', '511', '515'], ['NY', '77', '495', '505'], ['NH', '72', '520', '516'], ['RI', '71', '501', '499'], ['PA', '71', '500', '499'], ['VT', '69', '511', '506'], ['ME', '69', '506', '500'], ['VA', '68', '510', '501'], ['DE', '67', '501', '499'], ['MD', '65', '508', '510'], ['NC', '65', '493', '499'], ['GA', '63', '491', '489'], ['IN', '60', '499', '501'], ['SC', '57', '486', '488'], ['DC', '56', '482', '474'], ['OR', '55', '526', '526'], ['FL', '54', '498', '499'], ['WA', '53', '527', '527'], ['TX', '53', '493', '499'], ['HI', '52', '485', '515'], ['AK', '51', '514', '510'], ['CA', '51', '498', '517'], ['AZ', '34', '523', '525'], ['NV', '33', '509', '515'], ['CO', '31', '539', '542'], ['OH', '26', '534', '439'], ['MT', '23', '539', '539'], ['WV', '18', '527', '512'], ['ID', '17', '543', '542'], ['TN', '13', '562', '553'], ['NM', '13', '551', '542'], ['IL', '12', '576', '589'], ['KY', '12', '550', '550'], ['WY', '11', '547', '545'], ['MI', '11', '561', '572'], ['MN', '9', '580', '589'], ['KS', '9', '577', '580'], ['AL', '9', '559', '554'], ['NE', '8', '562', '568'], ['OK', '8', '567', '561'], ['MO', '8', '577', '577'], ['LA', '7', '564', '562'], ['WI', '6', '584', '596'], ['AR', '6', '562', '550'], ['UT', '5', '575', '570'], ['IA', '5', '593', '603'], ['SD', '4', '577', '582'], ['ND', '4', '592', '599'], ['MS', '4', '566', '551'], ['All', '45', '506', '514']]

# %% [markdown]
# ##### 6. Extract a list of the labels from the data, and remove them from the data.

# %%
#Strip off the "Header" row with column labels
labels = sat_score_list[0]
del sat_score_list[0]
print labels
print

#remove "All" from data
sat_score_list = sat_score_list[:-1]
print sat_score_list
# Out:
# ['State', 'Rate', 'Verbal', 'Math']
#
# [['CT', '82', '509', '510'], ['NJ', '81', '499', '513'], ['MA', '79', '511', '515'], ['NY', '77', '495', '505'], ['NH', '72', '520', '516'], ['RI', '71', '501', '499'], ['PA', '71', '500', '499'], ['VT', '69', '511', '506'], ['ME', '69', '506', '500'], ['VA', '68', '510', '501'], ['DE', '67', '501', '499'], ['MD', '65', '508', '510'], ['NC', '65', '493', '499'], ['GA', '63', '491', '489'], ['IN', '60', '499', '501'], ['SC', '57', '486', '488'], ['DC', '56', '482', '474'], ['OR', '55', '526', '526'], ['FL', '54', '498', '499'], ['WA', '53', '527', '527'], ['TX', '53', '493', '499'], ['HI', '52', '485', '515'], ['AK', '51', '514', '510'], ['CA', '51', '498', '517'], ['AZ', '34', '523', '525'], ['NV', '33', '509', '515'], ['CO', '31', '539', '542'], ['OH', '26', '534', '439'], ['MT', '23', '539', '539'], ['WV', '18', '527', '512'], ['ID', '17', '543', '542'], ['TN', '13', '562', '553'], ['NM', '13', '551', '542'], ['IL', '12', '576', '589'], ['KY', '12', '550', '550'], ['WY', '11', '547', '545'], ['MI', '11', '561', '572'], ['MN', '9', '580', '589'], ['KS', '9', '577', '580'], ['AL', '9', '559', '554'], ['NE', '8', '562', '568'], ['OK', '8', '567', '561'], ['MO', '8', '577', '577'], ['LA', '7', '564', '562'], ['WI', '6', '584', '596'], ['AR', '6', '562', '550'], ['UT', '5', '575', '570'], ['IA', '5', '593', '603'], ['SD', '4', '577', '582'], ['ND', '4', '592', '599'], ['MS', '4', '566', '551']]

# %% [markdown]
# ##### 7. Create a list of State names extracted from the data. (Hint: use the list of labels to index on the State column)

# %%
search_for = "State"
stIndex = labels.index(search_for)
state_list = [x[stIndex] for x in sat_score_list]
state_list
# Out:
# ['CT', 'NJ', 'MA', 'NY', 'NH', 'RI', 'PA', 'VT', 'ME', 'VA', 'DE', 'MD', 'NC', 'GA', 'IN', 'SC', 'DC', 'OR', 'FL', 'WA', 'TX', 'HI', 'AK', 'CA', 'AZ', 'NV', 'CO', 'OH', 'MT', 'WV', 'ID', 'TN', 'NM', 'IL', 'KY', 'WY', 'MI', 'MN', 'KS', 'AL', 'NE', 'OK', 'MO', 'LA', 'WI', 'AR', 'UT', 'IA', 'SD', 'ND', 'MS']

# %% [markdown]
# ##### 8. Print the types of each column

# %%
type_list = [type(x) for x in sat_score_list[0]]
type_list
# Out:
# [<type 'str'>, <type 'str'>, <type 'str'>, <type 'str'>]

# %% [markdown]
# ##### 9. Do any types need to be reassigned? If so, go ahead and do it.

# %%
# Because we will be using them for means and standard deviations, it is best to cast them to 'float' types. 
sat_score_list = [[x,float(y),float(z),float(a)] for x,y,z,a in sat_score_list] #unpack, cast and repack

type_list = [type(x) for x in sat_score_list[0]]
type_list
# Out:
# [<type 'str'>, <type 'float'>, <type 'float'>, <type 'float'>]

# %% [markdown]
# ##### 10. Create a dictionary for each column mapping the State to its respective value for that column.

# %%
stRate_dict = {s:r for s,r,v,m in sat_score_list}
stVerbal_dict = {s:v for s,r,v,m in sat_score_list}
stMath_dict = {s:m for s,r,v,m in sat_score_list}
print stRate_dict
print ""
print stVerbal_dict
print ""
print stMath_dict
# Out:
# {'WA': 53.0, 'DE': 67.0, 'DC': 56.0, 'WI': 6.0, 'WV': 18.0, 'HI': 52.0, 'FL': 54.0, 'WY': 11.0, 'NH': 72.0, 'NJ': 81.0, 'NM': 13.0, 'TX': 53.0, 'LA': 7.0, 'NC': 65.0, 'ND': 4.0, 'NE': 8.0, 'TN': 13.0, 'NY': 77.0, 'PA': 71.0, 'RI': 71.0, 'NV': 33.0, 'VA': 68.0, 'CO': 31.0, 'AK': 51.0, 'AL': 9.0, 'AR': 6.0, 'VT': 69.0, 'IL': 12.0, 'GA': 63.0, 'IN': 60.0, 'IA': 5.0, 'OK': 8.0, 'AZ': 34.0, 'CA': 51.0, 'ID': 17.0, 'CT': 82.0, 'ME': 69.0, 'MD': 65.0, 'MA': 79.0, 'OH': 26.0, 'UT': 5.0, 'MO': 8.0, 'MN': 9.0, 'MI': 11.0, 'KS': 9.0, 'MT': 23.0, 'MS': 4.0, 'SC': 57.0, 'KY': 12.0, 'OR': 55.0, 'SD': 4.0}
#
# {'WA': 527.0, 'DE': 501.0, 'DC': 482.0, 'WI': 584.0, 'WV': 527.0, 'HI': 485.0, 'FL': 498.0, 'WY': 547.0, 'NH': 520.0, 'NJ': 499.0, 'NM': 551.0, 'TX': 493.0, 'LA': 564.0, 'NC': 493.0, 'ND': 592.0, 'NE': 562.0, 'TN': 562.0, 'NY': 495.0, 'PA': 500.0, 'RI': 501.0, 'NV': 509.0, 'VA': 510.0, 'CO': 539.0, 'AK': 514.0, 'AL': 559.0, 'AR': 562.0, 'VT': 511.0, 'IL': 576.0, 'GA': 491.0, 'IN': 499.0, 'IA': 593.0, 'OK': 567.0, 'AZ': 523.0, 'CA': 498.0, 'ID': 543.0, 'CT': 509.0, 'ME': 506.0, 'MD': 508.0, 'MA': 511.0, 'OH': 534.0, 'UT': 575.0, 'MO': 577.0, 'MN': 580.0, 'MI': 561.0, 'KS': 577.0, 'MT': 539.0, 'MS': 566.0, 'SC': 486.0, 'KY': 550.0, 'OR': 526.0, 'SD': 577.0}
#
# {'WA': 527.0, 'DE': 499.0, 'DC': 474.0, 'WI': 596.0, 'WV': 512.0, 'HI': 515.0, 'FL': 499.0, 'WY': 545.0, 'NH': 516.0, 'NJ': 513.0, 'NM': 542.0, 'TX': 499.0, 'LA': 562.0, 'NC': 499.0, 'ND': 599.0, 'NE': 568.0, 'TN': 553.0, 'NY': 505.0, 'PA': 499.0, 'RI': 499.0, 'NV': 515.0, 'VA': 501.0, 'CO': 542.0, 'AK': 510.0, 'AL': 554.0, 'AR': 550.0, 'VT': 506.0, 'IL': 589.0, 'GA': 489.0, 'IN': 501.0, 'IA': 603.0, 'OK': 561.0, 'AZ': 525.0, 'CA': 517.0, 'ID': 542.0, 'CT': 510.0, 'ME': 500.0, 'MD': 510.0, 'MA': 515.0, 'OH': 439.0, 'UT': 570.0, 'MO': 577.0, 'MN': 589.0, 'MI': 572.0, 'KS': 580.0, 'MT': 539.0, 'MS': 551.0, 'SC': 488.0, 'KY': 550.0, 'OR': 526.0, 'SD': 582.0}

# %% [markdown]
# ##### 11. Create a dictionary with the values for each of the numeric columns

# %%
search_for = labels[-3:] #grab last 3 columns Rate, Verbal Math
scores_dict = {}
for score_type in search_for: #iterate over the columns above
    stIndex = labels.index(score_type) #get index of the column
    score_list = [float(x[stIndex]) for x in sat_score_list] #CAST FLOAT & create a list of values from the specfic column
    scores_dict.update({score_type:score_list}) 
scores_dict
# Out:
# {'Rate': [82.0, 81.0, 79.0, 77.0, 72.0, 71.0, 71.0, 69.0, 69.0, 68.0, 67.0, 65.0, 65.0, 63.0, 60.0, 57.0, 56.0, 55.0, 54.0, 53.0, 53.0, 52.0, 51.0, 51.0, 34.0, 33.0, 31.0, 26.0, 23.0, 18.0, 17.0, 13.0, 13.0, 12.0, 12.0, 11.0, 11.0, 9.0, 9.0, 9.0, 8.0, 8.0, 8.0, 7.0, 6.0, 6.0, 5.0, 5.0, 4.0, 4.0, 4.0], 'Math': [510.0, 513.0, 515.0, 505.0, 516.0, 499.0, 499.0, 506.0, 500.0, 501.0, 499.0, 510.0, 499.0, 489.0, 501.0, 488.0, 474.0, 526.0, 499.0, 527.0, 499.0, 515.0, 510.0, 517.0, 525.0, 515.0, 542.0, 439.0, 539.0, 512.0, 542.0, 553.0, 542.0, 589.0, 550.0, 545.0, 572.0, 589.0, 580.0, 554.0, 568.0, 561.0, 577.0, 562.0, 596.0, 550.0, 570.0, 603.0, 582.0, 599.0, 551.0], 'Verbal': [509.0, 499.0, 511.0, 495.0, 520.0, 501.0, 500.0, 511.0, 506.0, 510.0, 501.0, 508.0, 493.0, 491.0, 499.0, 486.0, 482.0, 526.0, 498.0, 527.0, 493.0, 485.0, 514.0, 498.0, 523.0, 509.0, 539.0, 534.0, 539.0, 527.0, 543.0, 562.0, 551.0, 576.0, 550.0, 547.0, 561.0, 580.0, 577.0, 559.0, 562.0, 567.0, 577.0, 564.0, 584.0, 562.0, 575.0, 593.0, 577.0, 592.0, 566.0]}

# %% [markdown]
# ## Step 3: Describe the data

# %% [markdown]
# ##### 12. Print the min and max of each column

# %%
import numpy as np

print "Minimums"
for keys in scores_dict:
    print keys, min(scores_dict[keys])
print ""    
print "Maximums"
for keys in scores_dict:
    print keys, max(scores_dict[keys])    
print    
print "Means"
for keys in scores_dict:
    print keys, np.mean(scores_dict[keys])
# Out:
# Minimums
# Rate 4.0
# Math 439.0
# Verbal 482.0
#
# Maximums
# Rate 82.0
# Math 603.0
# Verbal 593.0
#
# Means
# Rate 37.0
# Math 531.843137255
# Verbal 532.529411765

# %% [markdown]
# ##### 13. Write a function using only list comprehensions, no loops, to compute Standard Deviation. Print the Standard Deviation of each numeric column.

# %%
#scores_dict
import numpy
import math

def std_dev(list):
    standDev = (sum([(x-sum(x for x in list)/len(list))**2 for x in list])/len(list))**0.5
    return standDev

print "Standard Devition: THE L.C. WAY"  
for label in labels[-3:]:
    print "%s: %f" % (label, std_dev(scores_dict[label])) # WINNER!!!

def NP_std_dev(list):
    array = numpy.array(list)
    return numpy.std(array)
#print scores_dict

print "\nStandard Devition: THE NUMPY WAY"
for label in labels[-3:]:
    print "%s: %f" % (label, NP_std_dev(scores_dict[label])) # WINNER!!!
# Out:
# Standard Devition: THE L.C. WAY
# Rate: 27.279239
# Verbal: 33.031983
# Math: 35.929873
#
# Standard Devition: THE NUMPY WAY
# Rate: 27.279239
# Verbal: 33.031983
# Math: 35.929873

# %% [markdown]
# ## Step 4: Visualize the data

# %% [markdown]
# ##### 14. Using MatPlotLib and PyPlot, plot the distribution of the Rate using histograms.

# %%
import numpy as np
import scipy.stats as stats
import csv
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

def plt_distribution_plotter(column,data):
    fig, ax = plt.subplots(figsize=(7,4))
    n, bins, patches = plt.hist(data, 25, histtype='stepfilled')
    ax.set_title('Distribution of '+ column, fontsize=18, y=1.01)
    plt.setp(patches, 'facecolor', 'g', 'alpha', 0.2)

def sns_distribution_plotter(column, data):
    sns.set(rc={"figure.figsize": (7, 4)})
    sns.set_style("white")
    dist = sns.distplot(data, hist_kws={'alpha':0.2},bins=12)
    dist.set_title('Distribution of ' + column + '\n', fontsize=16)

# %%
sns_distribution_plotter("Rate",scores_dict["Rate"])
plt_distribution_plotter("Rate",scores_dict["Rate"])

# %% [markdown]
# ##### 15. Plot the Math distribution

# %%
    
sns_distribution_plotter("Math",scores_dict["Math"])
plt_distribution_plotter("Math",scores_dict["Math"])

# %% [markdown]
# ##### 16. Plot the Verbal distribution

# %%
    
sns_distribution_plotter("Verbal",scores_dict["Verbal"])
plt_distribution_plotter("Verbal",scores_dict["Verbal"])

# %% [markdown]
# ##### 17. What is the typical assumption for data distribution?

# %% [markdown]
# The typical assumption regarding the distribution of the data is that it is "normal" and follows the 68-95-99.7 rule with regards to STDEVs. That is, 68% ofthe data is within 1-StDev, 95% within 2 StDevs and 99.7% within 3 StDevs

# %% [markdown]
# ##### 18. Does that distribution hold true for our data?

# %% [markdown]
# The Verbal and the Rate data seem to be bi-modal, that is, they have 2 distinct "humps" which represent 2 distinct disjointed "peaks" in the data. The Math data seems to be more representative of a normal distribution however it is skewed slightly left.

# %% [markdown]
# ##### 19. Plot some scatterplots. **BONUS**: Use a PyPlot `figure` to present multiple plots at once.

# %%
f, axarr = plt.subplots(1, 3)
axarr[0].scatter(scores_dict['Rate'], scores_dict['Math'], alpha=0.5)
axarr[0].set_title('Rate vs. Math')
axarr[1].scatter(scores_dict['Rate'], scores_dict['Verbal'], alpha=0.5)
axarr[1].set_title('Rate vs. Verbal')
axarr[2].scatter(scores_dict['Math'], scores_dict['Verbal'], alpha=0.5)
axarr[2].set_title('Verbal vs. Math')

# %%
plt.scatter(scores_dict['Math'], scores_dict['Verbal'], alpha=0.5)
plt.xlabel('Math Score')
plt.ylabel('Verbal Score')
plt.title('Math Score vs. Verbal Score')
plt.show()

# %%
plt.scatter(scores_dict['Rate'], scores_dict['Verbal'], alpha=0.5)
plt.xlabel('Participation Rate')
plt.ylabel('Verbal Score')
plt.title('Participation Rate vs. Verbal Score')
plt.show()

# %%
plt.scatter(scores_dict['Rate'], scores_dict['Math'], alpha=0.5)
plt.xlabel('Participation Rate')
plt.ylabel('Math Score')
plt.title('Participation Rate vs. Math Score')
plt.show()

# %% [markdown]
# ##### 20. Are there any interesting relationships to note?

# %% [markdown]
# In the States which had lower participation rates, the students scored higher. This may be because only the most talented people actually sit for the test. As state participation rises, scores tend to be less varied.
#
# Not surprisingly, the relationship between the Math and Varbal scores seems to be highly correlated suggesting that if we know the value of 1 score, we can make a good estimation of the value of the 2nd score. This correlation also suggests that, generally, the difficulty of math and verbal are about equal.

# %% [markdown]
# ##### 21. Create box plots for each variable.

# %%
import seaborn as sns
scores = scores_dict['Rate']
sns.set_style("whitegrid")

#print scores
fig, ax = plt.subplots(figsize=(3,5))
ax = sns.boxplot(y=scores, showmeans=True)
ax.set_title('Distribution of Rate', fontsize=18, y=1.01)
ax.set_ylabel('Rate')

# %%
import seaborn as sns
scores = scores_dict['Verbal']
sns.set_style("whitegrid")
#print scores
fig, ax = plt.subplots(figsize=(3,5))
ax = sns.boxplot(y=scores,showmeans=True)
ax.set_title('Distribution of Verbal', fontsize=18, y=1.01)
ax.set_ylabel('Verbal Score')

# %%
import seaborn as sns
scores = scores_dict['Math']
sns.set_style("whitegrid")
#print scores
fig, ax = plt.subplots(figsize=(3,5))
ax = sns.boxplot(y=scores, showmeans=True)
ax.set_ylabel('Math Score')
ax.set_title('Distribution of Math', fontsize=18, y=1.01)

# %%
scoresM = scores_dict['Math']
scoresV = scores_dict['Verbal']
data = [scoresM, scoresV]

fig, ax = plt.subplots(figsize=(3,5))
labels = ['','Math','Verbal']
ax.set_xticklabels(labels)
ax = plt.boxplot(data, showmeans=True)
plt.xticks(range(3),labels)
plt.show()

# %% [markdown]
# ##### BONUS: Using Tableau, create a heat map for each variable using a map of the US.

# %% [markdown]
# ![](./tableau_math.png "Math Scores")
# ![](./tableau_verbal.png "Verbal Scores")
# ![](./tableau_rate1.png "Participation Rate")
