# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/jfreeley/GA-DSI/DSI_IMAGE/curriculum/week-04/4.1-lab-webscraping/scrape.csv')

# %%
list = df['location'].drop_duplicates().tolist()

# %%
list
# Out:
# ['Orangeburg, NY 10962',
#  'Washington, DC',
#  'Oriskany, NY',
#  'New York, NY 10011 (Chelsea area)',
#  'Macon, GA',
#  'Richmond, VA',
#  'Jacksonville, FL',
#  'Queens, NY',
#  'San Antonio, TX',
#  'Atlanta, GA',
#  'Warren, MI',
#  'New York, NY',
#  'New York, NY 10001 (Chelsea area)',
#  'Dearborn, MI',
#  'South San Francisco, CA',
#  'San Francisco, CA',
#  'Boston, MA',
#  'Dallas-Fort Worth, TX',
#  'New York, NY 10017 (Midtown area)',
#  'Sunnyvale, CA 94089',
#  'Portland, OR 97201 (Homestead area)',
#  'Mountain View, CA 94043',
#  'Indianapolis, IN',
#  'Cambridge, MA',
#  'Miami, FL',
#  'Dearborn, MI 48124',
#  'Palo Alto, CA',
#  'San Bruno, CA',
#  'Houston, TX',
#  'New York, NY 10111 (Midtown area)',
#  'Chicago, IL',
#  'New York, NY 10154 (Midtown area)',
#  'New York, NY 10271 (Financial District area)',
#  'Detroit, MI 48202 (New Center area)',
#  'Baltimore, MD',
#  'Pasadena, CA',
#  'San Diego, CA',
#  'Los Gatos, CA',
#  'Morgantown, WV',
# ...
