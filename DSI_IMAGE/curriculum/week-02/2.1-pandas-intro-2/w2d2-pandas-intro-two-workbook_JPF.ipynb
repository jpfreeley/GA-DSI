# %% [markdown]
# # ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) Intro to Pandas 2
# Week 2 | Day 2

# %% [markdown]
# ### LEARNING OBJECTIVES
# *After this lesson, you will be able to:*
# - Use the .loc function to slice
# - Set and reset DataFrame Indices
# - Use .isin()
# - Perform boolean indexing on dataframes
# - Perform math functions on pandas Series

# %% [markdown]
# ## Recap of yesterday

# %% [markdown]
# ### Importing pandas:
# ```python
# import pandas as pd
# ```
#
# ### Reading in a csv:
#
# ```python
# df = pd.read_csv()
# ```
#
# ### Viewing the head and tail
#
# ```python
# df.head()
# df.tail()
# ```
#
# ### Viewing the columns and the index
# ```python
# df.columns
# df.index
# ```

# %% [markdown]
# ### Data type info
# ```python
# df.info()
# ```
#
# ### Summary statistics
# ```python
# df.describe()
# df['some_column_name'].max()
# df['some_column_name'].min()
# ```
#
# ### Uniques
# ```python
# df['some_column_name'].nunique()
# df['some_column_name'].unique()
# ```
#
# ### Creating a histogram
# ```python
# df['some_column_name'].hist()
# ```

# %% [markdown]
# ## Slicing with .iloc

# %%
# import pandas
import pandas as pd

# create a dictionary
numbs = {'ones': [1, 2, 3, 4], 'tens': [10, 20, 30, 40], 'hundos': [100, 200, 300, 400]}

# pass dictionary into DataFrame and set the columns to keep the order
df = pd.DataFrame(numbs, columns=['ones', 'tens', 'hundos'])

# %% [markdown]
# ### Slicing with .iloc

# %%
df.iloc[0:2,0:1]
# Out:
#    ones
# 0     1
# 1     2

# %% [markdown]
# ### How do we get column 1?

# %%
# solution

df.iloc[:, 0:1]
# Out:
#    ones
# 0     1
# 1     2
# 2     3
# 3     4

# %% [markdown]
# ### How do we turn it into a DataFrame?

# %%
df.iloc[:, 0].to_frame()
# Out:
#    ones
# 0     1
# 1     2
# 2     3
# 3     4

# %% [markdown]
# ## How do we get the first  3 rows and 2 columns?

# %%
df.iloc[:3, 0:2]
# Out:
#    ones  tens
# 0     1    10
# 1     2    20
# 2     3    30

# %% [markdown]
# ### Notice this is exclusive - we get 0, 1, 2 for rows and 0,1 for columns

# %% [markdown]
# ### One more. How do we get all rows and column 0 and 2?

# %%
df.iloc[:, [0,2]]
# Out:
#    ones  hundos
# 0     1     100
# 1     2     200
# 2     3     300
# 3     4     400

# %% [markdown]
# ### Can we get only columns with an 'o' in them with iloc?

# %%
df.iloc[:, [x for x in df.columns if 'o' in x]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-e9cda95aaa47> in <module>()
# ----> 1 df.iloc[:, [x for x in df.columns if 'o' in x]]
#
# /Applications/anaconda/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1292
#    1293         if type(key) is tuple:
# -> 1294             return self._getitem_tuple(key)
#    1295         else:
#    1296             return self._getitem_axis(key, axis=0)
#
# /Applications/anaconda/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#    1542     def _getitem_tuple(self, tup):
#    1543
# -> 1544         self._has_valid_tuple(tup)
#    1545         try:
#    1546             return self._getitem_lowerdim(tup)
#
# /Applications/anaconda/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_tuple(self, key)
#     140             if i >= self.obj.ndim:
#     141                 raise IndexingError('Too many indexers')
# --> 142             if not self._has_valid_type(k, i):
#     143                 raise ValueError("Location based indexing can only have [%s] "
#     144                                  "types" % self._valid_types)
#
# /Applications/anaconda/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_type(self, key, axis)
#    1512             return self._is_valid_integer(key, axis)
#    1513         elif is_list_like_indexer(key):
# -> 1514             return self._is_valid_list_like(key, axis)
#    1515         return False
#    1516
#
# /Applications/anaconda/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _is_valid_list_like(self, key, axis)
#    1535         ax = self.obj._get_axis(axis)
#    1536         l = len(ax)
# -> 1537         if len(arr) and (arr.max() >= l or arr.min() < -l):
#    1538             raise IndexError("positional indexers are out-of-bounds")
#    1539
#
# /Applications/anaconda/anaconda/lib/python2.7/site-packages/numpy/core/_methods.pyc in _amax(a, axis, out, keepdims)
#      24 # small reductions
#      25 def _amax(a, axis=None, out=None, keepdims=False):
# ---> 26     return umr_maximum(a, axis, None, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
#
# TypeError: cannot perform reduce with flexible type

# %% [markdown]
# ## No.

# %% [markdown]
# ## Introducing .loc

# %%
df.loc[:, [x for x in df.columns if 'o' in x]]

# %% [markdown]
# ### .loc allows us to use combined slicing: numeric and named

# %%
df.loc[:3, ['ones', 'tens']]

# %% [markdown]
# ### Notice that it is inclusive! It includes the last item listed

# %% [markdown]
# ### Notice we can't use the .iloc syntax of all numerics

# %%
df.loc[:2, 1]

# %% [markdown]
# ## Let's change the index

# %%
from string import ascii_lowercase

# change the index to be lower case letters
df.index = [x for x in ascii_lowercase[:len(df.index)]]

# %%
df

# %% [markdown]
# ## Now we'll use .loc to slice with a named index

# %%
# list of indicies
df.loc[['a','c'], :]

# %%
# slicing with named indices
df.loc['b':, :]

# %%
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
state_df = pd.DataFrame([states.keys(),\
              states.values(),\
              [len(x) for x in states.values()]],\
              index=['abbreviation', 'name', 'name_length']).T

# %% [markdown]
# ## DataFrame of state names

# %%
# we have the index as what currently?
state_df
# Out:
#    abbreviation            name name_length
# 0            WA      Washington          10
# 1            WI       Wisconsin           9
# 2            WV   West Virginia          13
# 3            FL         Florida           7
# 4            WY         Wyoming           7
# 5            NH   New Hampshire          13
# 6            NJ      New Jersey          10
# 7            NM      New Mexico          10
# 8            NC  North Carolina          14
# 9            ND    North Dakota          12
# 10           NE        Nebraska           8
# 11           NY        New York           8
# 12           RI    Rhode Island          12
# 13           NV          Nevada           6
# 14           CO        Colorado           8
# 15           CA      California          10
# 16           GA         Georgia           7
# 17           CT     Connecticut          11
# 18           OK        Oklahoma           8
# 19           OH            Ohio           4
# 20           KS          Kansas           6
# 21           SC  South Carolina          14
# 22           KY        Kentucky           8
# 23           OR          Oregon           6
# 24           SD    South Dakota          12
# 25           DE        Delaware           8
# 26           HI          Hawaii           6
# 27           TX           Texas           5
# 28           LA       Louisiana           9
# 29           TN       Tennessee           9
# 30           PA    Pennsylvania          12
# 31           VA        Virginia           8
# 32           AK          Alaska           6
# 33           AL         Alabama           7
# 34           AR        Arkansas           8
# 35           VT         Vermont           7
# 36           IL        Illinois           8
# 37           IN         Indiana           7
# 38           IA            Iowa           4
# 39           AZ         Arizona           7
# 40           ID           Idaho           5
# 41           ME           Maine           5
# 42           MD        Maryland           8
# 43           MA   Massachusetts          13
# 44           UT            Utah           4
# 45           MO        Missouri           8
# 46           MN       Minnesota           9
# 47           MI        Michigan           8
# 48           MT         Montana           7
# 49           MS     Mississippi          11

# %% [markdown]
# ## Let's change the index

# %% [markdown]
# We have numbers as the index, let's make the index the state's abbreviation

# %%
state_df.set_index('abbreviation')
# Out:
#                         name name_length
# abbreviation
# WA                Washington          10
# WI                 Wisconsin           9
# WV             West Virginia          13
# FL                   Florida           7
# WY                   Wyoming           7
# NH             New Hampshire          13
# NJ                New Jersey          10
# NM                New Mexico          10
# NC            North Carolina          14
# ND              North Dakota          12
# NE                  Nebraska           8
# NY                  New York           8
# RI              Rhode Island          12
# NV                    Nevada           6
# CO                  Colorado           8
# CA                California          10
# GA                   Georgia           7
# CT               Connecticut          11
# OK                  Oklahoma           8
# OH                      Ohio           4
# KS                    Kansas           6
# SC            South Carolina          14
# KY                  Kentucky           8
# OR                    Oregon           6
# SD              South Dakota          12
# DE                  Delaware           8
# HI                    Hawaii           6
# TX                     Texas           5
# LA                 Louisiana           9
# TN                 Tennessee           9
# PA              Pennsylvania          12
# VA                  Virginia           8
# AK                    Alaska           6
# AL                   Alabama           7
# AR                  Arkansas           8
# VT                   Vermont           7
# IL                  Illinois           8
# IN                   Indiana           7
# IA                      Iowa           4
# AZ                   Arizona           7
# ID                     Idaho           5
# ME                     Maine           5
# MD                  Maryland           8
# MA             Massachusetts          13
# UT                      Utah           4
# MO                  Missouri           8
# MN                 Minnesota           9
# MI                  Michigan           8
# MT                   Montana           7
# MS               Mississippi          11

# %% [markdown]
# ## Notice that was just a view, did not change the data

# %%
state_df
# Out:
#    abbreviation            name name_length
# 0            WA      Washington          10
# 1            WI       Wisconsin           9
# 2            WV   West Virginia          13
# 3            FL         Florida           7
# 4            WY         Wyoming           7
# 5            NH   New Hampshire          13
# 6            NJ      New Jersey          10
# 7            NM      New Mexico          10
# 8            NC  North Carolina          14
# 9            ND    North Dakota          12
# 10           NE        Nebraska           8
# 11           NY        New York           8
# 12           RI    Rhode Island          12
# 13           NV          Nevada           6
# 14           CO        Colorado           8
# 15           CA      California          10
# 16           GA         Georgia           7
# 17           CT     Connecticut          11
# 18           OK        Oklahoma           8
# 19           OH            Ohio           4
# 20           KS          Kansas           6
# 21           SC  South Carolina          14
# 22           KY        Kentucky           8
# 23           OR          Oregon           6
# 24           SD    South Dakota          12
# 25           DE        Delaware           8
# 26           HI          Hawaii           6
# 27           TX           Texas           5
# 28           LA       Louisiana           9
# 29           TN       Tennessee           9
# 30           PA    Pennsylvania          12
# 31           VA        Virginia           8
# 32           AK          Alaska           6
# 33           AL         Alabama           7
# 34           AR        Arkansas           8
# 35           VT         Vermont           7
# 36           IL        Illinois           8
# 37           IN         Indiana           7
# 38           IA            Iowa           4
# 39           AZ         Arizona           7
# 40           ID           Idaho           5
# 41           ME           Maine           5
# 42           MD        Maryland           8
# 43           MA   Massachusetts          13
# 44           UT            Utah           4
# 45           MO        Missouri           8
# 46           MN       Minnesota           9
# 47           MI        Michigan           8
# 48           MT         Montana           7
# 49           MS     Mississippi          11

# %% [markdown]
# ## Have to save as a new DataFrame or use inplace=True

# %%
state_df.set_index(['abbreviation','name'], inplace=True)

# %% [markdown]
# ## Now we can see the changes 'stuck'

# %%
state_df
# Out:
#                             name_length
# abbreviation name
# WA           Washington              10
# WI           Wisconsin                9
# WV           West Virginia           13
# FL           Florida                  7
# WY           Wyoming                  7
# NH           New Hampshire           13
# NJ           New Jersey              10
# NM           New Mexico              10
# NC           North Carolina          14
# ND           North Dakota            12
# NE           Nebraska                 8
# NY           New York                 8
# RI           Rhode Island            12
# NV           Nevada                   6
# CO           Colorado                 8
# CA           California              10
# GA           Georgia                  7
# CT           Connecticut             11
# OK           Oklahoma                 8
# OH           Ohio                     4
# KS           Kansas                   6
# SC           South Carolina          14
# KY           Kentucky                 8
# OR           Oregon                   6
# SD           South Dakota            12
# DE           Delaware                 8
# HI           Hawaii                   6
# TX           Texas                    5
# LA           Louisiana                9
# TN           Tennessee                9
# PA           Pennsylvania            12
# VA           Virginia                 8
# AK           Alaska                   6
# AL           Alabama                  7
# AR           Arkansas                 8
# VT           Vermont                  7
# IL           Illinois                 8
# IN           Indiana                  7
# IA           Iowa                     4
# AZ           Arizona                  7
# ID           Idaho                    5
# ME           Maine                    5
# MD           Maryland                 8
# MA           Massachusetts           13
# UT           Utah                     4
# MO           Missouri                 8
# MN           Minnesota                9
# MI           Michigan                 8
# MT           Montana                  7
# MS           Mississippi             11

# %% [markdown]
# ## What if we want to go back?

# %%
state_df
# Out:
#                             name_length
# abbreviation name
# WA           Washington              10
# WI           Wisconsin                9
# WV           West Virginia           13
# FL           Florida                  7
# WY           Wyoming                  7
# NH           New Hampshire           13
# NJ           New Jersey              10
# NM           New Mexico              10
# NC           North Carolina          14
# ND           North Dakota            12
# NE           Nebraska                 8
# NY           New York                 8
# RI           Rhode Island            12
# NV           Nevada                   6
# CO           Colorado                 8
# CA           California              10
# GA           Georgia                  7
# CT           Connecticut             11
# OK           Oklahoma                 8
# OH           Ohio                     4
# KS           Kansas                   6
# SC           South Carolina          14
# KY           Kentucky                 8
# OR           Oregon                   6
# SD           South Dakota            12
# DE           Delaware                 8
# HI           Hawaii                   6
# TX           Texas                    5
# LA           Louisiana                9
# TN           Tennessee                9
# PA           Pennsylvania            12
# VA           Virginia                 8
# AK           Alaska                   6
# AL           Alabama                  7
# AR           Arkansas                 8
# VT           Vermont                  7
# IL           Illinois                 8
# IN           Indiana                  7
# IA           Iowa                     4
# AZ           Arizona                  7
# ID           Idaho                    5
# ME           Maine                    5
# MD           Maryland                 8
# MA           Massachusetts           13
# UT           Utah                     4
# MO           Missouri                 8
# MN           Minnesota                9
# MI           Michigan                 8
# MT           Montana                  7
# MS           Mississippi             11

# %% [markdown]
# ## Need to reset it!

# %%
state_df.reset_index(inplace=True)

# %%
state_df
# Out:
#    abbreviation            name name_length
# 0            WA      Washington          10
# 1            WI       Wisconsin           9
# 2            WV   West Virginia          13
# 3            FL         Florida           7
# 4            WY         Wyoming           7
# 5            NH   New Hampshire          13
# 6            NJ      New Jersey          10
# 7            NM      New Mexico          10
# 8            NC  North Carolina          14
# 9            ND    North Dakota          12
# 10           NE        Nebraska           8
# 11           NY        New York           8
# 12           RI    Rhode Island          12
# 13           NV          Nevada           6
# 14           CO        Colorado           8
# 15           CA      California          10
# 16           GA         Georgia           7
# 17           CT     Connecticut          11
# 18           OK        Oklahoma           8
# 19           OH            Ohio           4
# 20           KS          Kansas           6
# 21           SC  South Carolina          14
# 22           KY        Kentucky           8
# 23           OR          Oregon           6
# 24           SD    South Dakota          12
# 25           DE        Delaware           8
# 26           HI          Hawaii           6
# 27           TX           Texas           5
# 28           LA       Louisiana           9
# 29           TN       Tennessee           9
# 30           PA    Pennsylvania          12
# 31           VA        Virginia           8
# 32           AK          Alaska           6
# 33           AL         Alabama           7
# 34           AR        Arkansas           8
# 35           VT         Vermont           7
# 36           IL        Illinois           8
# 37           IN         Indiana           7
# 38           IA            Iowa           4
# 39           AZ         Arizona           7
# 40           ID           Idaho           5
# 41           ME           Maine           5
# 42           MD        Maryland           8
# 43           MA   Massachusetts          13
# 44           UT            Utah           4
# 45           MO        Missouri           8
# 46           MN       Minnesota           9
# 47           MI        Michigan           8
# 48           MT         Montana           7
# 49           MS     Mississippi          11

# %% [markdown]
# ## Exercise
#
# Using the states_df:
# - set the index to the state name and save it as new_state
# - use the .loc method to select all the states that begin with the letter 'N'
# - reset the index back to a zero-based index and do so inplace

# %%
new_state = state_df.set_index(['name'])
new_state.head()
# Out:
#               abbreviation name_length
# name
# Washington              WA          10
# Wisconsin               WI           9
# West Virginia           WV          13
# Florida                 FL           7
# Wyoming                 WY           7

# %%
new_state.loc[[x for x in new_state.index if "N" in x]]
# Out:
#                abbreviation name_length
# name
# New Hampshire            NH          13
# New Jersey               NJ          10
# New Mexico               NM          10
# North Carolina           NC          14
# North Dakota             ND          12
# Nebraska                 NE           8
# New York                 NY           8
# Nevada                   NV           6

# %%
new_state.reset_index(inplace=True)
new_state.head()
# Out:
#             name abbreviation name_length
# 0     Washington           WA          10
# 1      Wisconsin           WI           9
# 2  West Virginia           WV          13
# 3        Florida           FL           7
# 4        Wyoming           WY           7

# %% [markdown]
# ## Using .isin()

# %%
state_df
# Out:
#    abbreviation            name name_length
# 0            WA      Washington          10
# 1            WI       Wisconsin           9
# 2            WV   West Virginia          13
# 3            FL         Florida           7
# 4            WY         Wyoming           7
# 5            NH   New Hampshire          13
# 6            NJ      New Jersey          10
# 7            NM      New Mexico          10
# 8            NC  North Carolina          14
# 9            ND    North Dakota          12
# 10           NE        Nebraska           8
# 11           NY        New York           8
# 12           RI    Rhode Island          12
# 13           NV          Nevada           6
# 14           CO        Colorado           8
# 15           CA      California          10
# 16           GA         Georgia           7
# 17           CT     Connecticut          11
# 18           OK        Oklahoma           8
# 19           OH            Ohio           4
# 20           KS          Kansas           6
# 21           SC  South Carolina          14
# 22           KY        Kentucky           8
# 23           OR          Oregon           6
# 24           SD    South Dakota          12
# 25           DE        Delaware           8
# 26           HI          Hawaii           6
# 27           TX           Texas           5
# 28           LA       Louisiana           9
# 29           TN       Tennessee           9
# 30           PA    Pennsylvania          12
# 31           VA        Virginia           8
# 32           AK          Alaska           6
# 33           AL         Alabama           7
# 34           AR        Arkansas           8
# 35           VT         Vermont           7
# 36           IL        Illinois           8
# 37           IN         Indiana           7
# 38           IA            Iowa           4
# 39           AZ         Arizona           7
# 40           ID           Idaho           5
# 41           ME           Maine           5
# 42           MD        Maryland           8
# 43           MA   Massachusetts          13
# 44           UT            Utah           4
# 45           MO        Missouri           8
# 46           MN       Minnesota           9
# 47           MI        Michigan           8
# 48           MT         Montana           7
# 49           MS     Mississippi          11

# %% [markdown]
# ## We get a boolean (True/False) Series back

# %%
states_with_direction = ['North Dakota', 'North Carolina',\
                         'South Carolina', 'South Dakota',\
                         'West Virginia']

state_df['name'].isin(states_with_direction)
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: name, dtype: bool

# %% [markdown]
# ## Wrapping that in state_df[ ] gives us only the True rows

# %%
state_df[state_df['name'].isin(states_with_direction)]
# Out:
#    abbreviation            name name_length
# 2            WV   West Virginia          13
# 8            NC  North Carolina          14
# 9            ND    North Dakota          12
# 21           SC  South Carolina          14
# 24           SD    South Dakota          12

# %% [markdown]
# ## Exercise
#
# Using the state_df DataFrame:
# - use .isin() to select only those rows that have a name_length of 10 or 12 characters
# - use another .isin() with a list comprehension to select only the columns that are abbreviated that begin with an 'N' or a 'S'

# %%
state_df
# Out:
#    abbreviation            name name_length
# 0            WA      Washington          10
# 1            WI       Wisconsin           9
# 2            WV   West Virginia          13
# 3            FL         Florida           7
# 4            WY         Wyoming           7
# 5            NH   New Hampshire          13
# 6            NJ      New Jersey          10
# 7            NM      New Mexico          10
# 8            NC  North Carolina          14
# 9            ND    North Dakota          12
# 10           NE        Nebraska           8
# 11           NY        New York           8
# 12           RI    Rhode Island          12
# 13           NV          Nevada           6
# 14           CO        Colorado           8
# 15           CA      California          10
# 16           GA         Georgia           7
# 17           CT     Connecticut          11
# 18           OK        Oklahoma           8
# 19           OH            Ohio           4
# 20           KS          Kansas           6
# 21           SC  South Carolina          14
# 22           KY        Kentucky           8
# 23           OR          Oregon           6
# 24           SD    South Dakota          12
# 25           DE        Delaware           8
# 26           HI          Hawaii           6
# 27           TX           Texas           5
# 28           LA       Louisiana           9
# 29           TN       Tennessee           9
# 30           PA    Pennsylvania          12
# 31           VA        Virginia           8
# 32           AK          Alaska           6
# 33           AL         Alabama           7
# 34           AR        Arkansas           8
# 35           VT         Vermont           7
# 36           IL        Illinois           8
# 37           IN         Indiana           7
# 38           IA            Iowa           4
# 39           AZ         Arizona           7
# 40           ID           Idaho           5
# 41           ME           Maine           5
# 42           MD        Maryland           8
# 43           MA   Massachusetts          13
# 44           UT            Utah           4
# 45           MO        Missouri           8
# 46           MN       Minnesota           9
# 47           MI        Michigan           8
# 48           MT         Montana           7
# 49           MS     Mississippi          11

# %%
state_df[state_df['name_length'].isin([10,12])]
#state_df
# Out:
#    abbreviation          name name_length
# 0            WA    Washington          10
# 6            NJ    New Jersey          10
# 7            NM    New Mexico          10
# 9            ND  North Dakota          12
# 12           RI  Rhode Island          12
# 15           CA    California          10
# 24           SD  South Dakota          12
# 30           PA  Pennsylvania          12

# %%
vowels = ['A','C']
state_df[\
         state_df['abbreviation']\
        .isin(\
              [x for x in state_df['abbreviation']\
               if x[0] in vowels or 'S' in x[0]\
              ]\
             )\
        ]
# Out:
#    abbreviation            name name_length
# 14           CO        Colorado           8
# 15           CA      California          10
# 17           CT     Connecticut          11
# 21           SC  South Carolina          14
# 24           SD    South Dakota          12
# 32           AK          Alaska           6
# 33           AL         Alabama           7
# 34           AR        Arkansas           8
# 39           AZ         Arizona           7

# %% [markdown]
# ## Futher into Boolean indexing

# %%
state_df['name_length'] > 10
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8      True
# 9      True
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43     True
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49     True
# Name: name_length, dtype: bool

# %% [markdown]
# ## Again, we can wrap that

# %%
# gives us the only rows that have a length greater than 10
state_df[state_df['name_length']>10]
# Out:
#    abbreviation            name name_length
# 2            WV   West Virginia          13
# 5            NH   New Hampshire          13
# 8            NC  North Carolina          14
# 9            ND    North Dakota          12
# 12           RI    Rhode Island          12
# 17           CT     Connecticut          11
# 21           SC  South Carolina          14
# 24           SD    South Dakota          12
# 30           PA    Pennsylvania          12
# 43           MA   Massachusetts          13
# 49           MS     Mississippi          11

# %% [markdown]
# ## Another example

# %%
state_df[state_df['name'].str.contains('South')]
# Out:
#    abbreviation            name name_length
# 21           SC  South Carolina          14
# 24           SD    South Dakota          12

# %% [markdown]
# ## Let's use an 'and' here to combine requirements

# %%
state_df[(state_df['name_length']>12)\
          & \
         #   & = AND
         (state_df['name'].str.contains('South'))]
# Out:
#    abbreviation            name name_length
# 21           SC  South Carolina          14

# %% [markdown]
# ## Let's use an 'or' statement

# %%
state_df[(state_df['name'].str.contains('North'))\
          | \
         # | = OR
         (state_df['name'].str.contains('South'))]
# Out:
#    abbreviation            name name_length
# 8            NC  North Carolina          14
# 9            ND    North Dakota          12
# 21           SC  South Carolina          14
# 24           SD    South Dakota          12

# %% [markdown]
# ## Exercise
#
# Using the state_df DataFrame:
# - use Boolean indexing to select all states with a y in their name
# - using the same code from the line above add another condition to only return states that have 10 or fewer characters in their name

# %%
state_df[(state_df['name'].str.contains('y'))]
# Out:
#    abbreviation          name name_length
# 4            WY       Wyoming           7
# 6            NJ    New Jersey          10
# 22           KY      Kentucky           8
# 30           PA  Pennsylvania          12
# 42           MD      Maryland           8

# %%
state_df[\
         (state_df['name_length']<=10)\
          & \
         #   & = AND
         (state_df['name'].str.contains('y'))\
        ]
# Out:
#    abbreviation        name name_length
# 4            WY     Wyoming           7
# 6            NJ  New Jersey          10
# 22           KY    Kentucky           8
# 42           MD    Maryland           8

# %% [markdown]
# ## Math with pandas columns

# %%
state_df
# Out:
#    abbreviation            name name_length
# 0            WA      Washington          10
# 1            WI       Wisconsin           9
# 2            WV   West Virginia          13
# 3            FL         Florida           7
# 4            WY         Wyoming           7
# 5            NH   New Hampshire          13
# 6            NJ      New Jersey          10
# 7            NM      New Mexico          10
# 8            NC  North Carolina          14
# 9            ND    North Dakota          12
# 10           NE        Nebraska           8
# 11           NY        New York           8
# 12           RI    Rhode Island          12
# 13           NV          Nevada           6
# 14           CO        Colorado           8
# 15           CA      California          10
# 16           GA         Georgia           7
# 17           CT     Connecticut          11
# 18           OK        Oklahoma           8
# 19           OH            Ohio           4
# 20           KS          Kansas           6
# 21           SC  South Carolina          14
# 22           KY        Kentucky           8
# 23           OR          Oregon           6
# 24           SD    South Dakota          12
# 25           DE        Delaware           8
# 26           HI          Hawaii           6
# 27           TX           Texas           5
# 28           LA       Louisiana           9
# 29           TN       Tennessee           9
# 30           PA    Pennsylvania          12
# 31           VA        Virginia           8
# 32           AK          Alaska           6
# 33           AL         Alabama           7
# 34           AR        Arkansas           8
# 35           VT         Vermont           7
# 36           IL        Illinois           8
# 37           IN         Indiana           7
# 38           IA            Iowa           4
# 39           AZ         Arizona           7
# 40           ID           Idaho           5
# 41           ME           Maine           5
# 42           MD        Maryland           8
# 43           MA   Massachusetts          13
# 44           UT            Utah           4
# 45           MO        Missouri           8
# 46           MN       Minnesota           9
# 47           MI        Michigan           8
# 48           MT         Montana           7
# 49           MS     Mississippi          11

# %% [markdown]
# ## Let's add a new column that is 100x name_length

# %%
tmp_df = state_df.copy()

tmp_df['name_length_x100'] = tmp_df['name_length'] * 100
tmp_df['ones'] = 1
tmp_df
# Out:
#    abbreviation            name name_length name_length_x100  ones
# 0            WA      Washington          10             1000     1
# 1            WI       Wisconsin           9              900     1
# 2            WV   West Virginia          13             1300     1
# 3            FL         Florida           7              700     1
# 4            WY         Wyoming           7              700     1
# 5            NH   New Hampshire          13             1300     1
# 6            NJ      New Jersey          10             1000     1
# 7            NM      New Mexico          10             1000     1
# 8            NC  North Carolina          14             1400     1
# 9            ND    North Dakota          12             1200     1
# 10           NE        Nebraska           8              800     1
# 11           NY        New York           8              800     1
# 12           RI    Rhode Island          12             1200     1
# 13           NV          Nevada           6              600     1
# 14           CO        Colorado           8              800     1
# 15           CA      California          10             1000     1
# 16           GA         Georgia           7              700     1
# 17           CT     Connecticut          11             1100     1
# 18           OK        Oklahoma           8              800     1
# 19           OH            Ohio           4              400     1
# 20           KS          Kansas           6              600     1
# 21           SC  South Carolina          14             1400     1
# 22           KY        Kentucky           8              800     1
# 23           OR          Oregon           6              600     1
# 24           SD    South Dakota          12             1200     1
# 25           DE        Delaware           8              800     1
# 26           HI          Hawaii           6              600     1
# 27           TX           Texas           5              500     1
# 28           LA       Louisiana           9              900     1
# 29           TN       Tennessee           9              900     1
# 30           PA    Pennsylvania          12             1200     1
# 31           VA        Virginia           8              800     1
# 32           AK          Alaska           6              600     1
# 33           AL         Alabama           7              700     1
# 34           AR        Arkansas           8              800     1
# 35           VT         Vermont           7              700     1
# 36           IL        Illinois           8              800     1
# 37           IN         Indiana           7              700     1
# 38           IA            Iowa           4              400     1
# 39           AZ         Arizona           7              700     1
# 40           ID           Idaho           5              500     1
# 41           ME           Maine           5              500     1
# 42           MD        Maryland           8              800     1
# 43           MA   Massachusetts          13             1300     1
# 44           UT            Utah           4              400     1
# 45           MO        Missouri           8              800     1
# 46           MN       Minnesota           9              900     1
# 47           MI        Michigan           8              800     1
# 48           MT         Montana           7              700     1
# 49           MS     Mississippi          11             1100     1

# %% [markdown]
# ## Let's add two columns together

# %%
tmp_df['name_added_cols'] = tmp_df['name_length'] + tmp_df['name_length_x100']

tmp_df
# Out:
#    abbreviation            name name_length name_length_x100  ones  \
# 0            WA      Washington          10             1000     1
# 1            WI       Wisconsin           9              900     1
# 2            WV   West Virginia          13             1300     1
# 3            FL         Florida           7              700     1
# 4            WY         Wyoming           7              700     1
# 5            NH   New Hampshire          13             1300     1
# 6            NJ      New Jersey          10             1000     1
# 7            NM      New Mexico          10             1000     1
# 8            NC  North Carolina          14             1400     1
# 9            ND    North Dakota          12             1200     1
# 10           NE        Nebraska           8              800     1
# 11           NY        New York           8              800     1
# 12           RI    Rhode Island          12             1200     1
# 13           NV          Nevada           6              600     1
# 14           CO        Colorado           8              800     1
# 15           CA      California          10             1000     1
# 16           GA         Georgia           7              700     1
# 17           CT     Connecticut          11             1100     1
# 18           OK        Oklahoma           8              800     1
# 19           OH            Ohio           4              400     1
# 20           KS          Kansas           6              600     1
# 21           SC  South Carolina          14             1400     1
# 22           KY        Kentucky           8              800     1
# 23           OR          Oregon           6              600     1
# 24           SD    South Dakota          12             1200     1
# 25           DE        Delaware           8              800     1
# 26           HI          Hawaii           6              600     1
# 27           TX           Texas           5              500     1
# 28           LA       Louisiana           9              900     1
# 29           TN       Tennessee           9              900     1
# 30           PA    Pennsylvania          12             1200     1
# 31           VA        Virginia           8              800     1
# 32           AK          Alaska           6              600     1
# 33           AL         Alabama           7              700     1
# 34           AR        Arkansas           8              800     1
# 35           VT         Vermont           7              700     1
# 36           IL        Illinois           8              800     1
# 37           IN         Indiana           7              700     1
# 38           IA            Iowa           4              400     1
# 39           AZ         Arizona           7              700     1
# 40           ID           Idaho           5              500     1
# 41           ME           Maine           5              500     1
# 42           MD        Maryland           8              800     1
# 43           MA   Massachusetts          13             1300     1
# 44           UT            Utah           4              400     1
# 45           MO        Missouri           8              800     1
# 46           MN       Minnesota           9              900     1
# 47           MI        Michigan           8              800     1
# 48           MT         Montana           7              700     1
# 49           MS     Mississippi          11             1100     1
#
#    name_added_cols
# 0             1010
# 1              909
# 2             1313
# 3              707
# 4              707
# 5             1313
# 6             1010
# 7             1010
# 8             1414
# 9             1212
# 10             808
# 11             808
# 12            1212
# 13             606
# 14             808
# 15            1010
# 16             707
# 17            1111
# 18             808
# 19             404
# 20             606
# 21            1414
# 22             808
# 23             606
# 24            1212
# 25             808
# 26             606
# 27             505
# 28             909
# 29             909
# 30            1212
# 31             808
# 32             606
# 33             707
# 34             808
# 35             707
# 36             808
# 37             707
# 38             404
# 39             707
# 40             505
# 41             505
# 42             808
# 43            1313
# 44             404
# 45             808
# 46             909
# 47             808
# 48             707
# 49            1111

# %% [markdown]
# ## Exercise
#
# Using the state_df DataFrame again:
# - Save temp_df as a copy of state_df
# - Double the name_length column by adding it to itself
# - Double the doubled column you created by multiplying it by 2

# %%
temp_df = state_df.copy()
temp_df['name_lenx+x'] = temp_df['name_length'] + temp_df['name_length']
temp_df['name_len2x'] = temp_df['name_length'] * 2

temp_df
# Out:
#    abbreviation            name name_length name_lenx+x name_len2x
# 0            WA      Washington          10          20         20
# 1            WI       Wisconsin           9          18         18
# 2            WV   West Virginia          13          26         26
# 3            FL         Florida           7          14         14
# 4            WY         Wyoming           7          14         14
# 5            NH   New Hampshire          13          26         26
# 6            NJ      New Jersey          10          20         20
# 7            NM      New Mexico          10          20         20
# 8            NC  North Carolina          14          28         28
# 9            ND    North Dakota          12          24         24
# 10           NE        Nebraska           8          16         16
# 11           NY        New York           8          16         16
# 12           RI    Rhode Island          12          24         24
# 13           NV          Nevada           6          12         12
# 14           CO        Colorado           8          16         16
# 15           CA      California          10          20         20
# 16           GA         Georgia           7          14         14
# 17           CT     Connecticut          11          22         22
# 18           OK        Oklahoma           8          16         16
# 19           OH            Ohio           4           8          8
# 20           KS          Kansas           6          12         12
# 21           SC  South Carolina          14          28         28
# 22           KY        Kentucky           8          16         16
# 23           OR          Oregon           6          12         12
# 24           SD    South Dakota          12          24         24
# 25           DE        Delaware           8          16         16
# 26           HI          Hawaii           6          12         12
# 27           TX           Texas           5          10         10
# 28           LA       Louisiana           9          18         18
# 29           TN       Tennessee           9          18         18
# 30           PA    Pennsylvania          12          24         24
# 31           VA        Virginia           8          16         16
# 32           AK          Alaska           6          12         12
# 33           AL         Alabama           7          14         14
# 34           AR        Arkansas           8          16         16
# 35           VT         Vermont           7          14         14
# 36           IL        Illinois           8          16         16
# 37           IN         Indiana           7          14         14
# 38           IA            Iowa           4           8          8
# 39           AZ         Arizona           7          14         14
# 40           ID           Idaho           5          10         10
# 41           ME           Maine           5          10         10
# 42           MD        Maryland           8          16         16
# 43           MA   Massachusetts          13          26         26
# 44           UT            Utah           4           8          8
# 45           MO        Missouri           8          16         16
# 46           MN       Minnesota           9          18         18
# 47           MI        Michigan           8          16         16
# 48           MT         Montana           7          14         14
# 49           MS     Mississippi          11          22         22

# %% [markdown]
# ## Conclusion
#
# In this lecture we covered:
# - How to use the .loc function to slice and how it differs from .iloc
# - How to set and reset DataFrame Indices
# - How to use .isin()
# - How to perform boolean indexing on dataframes
# - How to combine conditions using '|' and '&'
# - How to perform math on pandas Series
